# %%
import yfinance as y #yahoo finance stock API
from datetime import timedelta,date # Date and Time data
import matplotlib.pyplot as py # plotting graph
import seaborn as sb #plotting graph
import plotly.graph_objects as plg #plotting graph

print("USE THE GIVEN CODES AS INPUT FOR YOUR DESIRED COMPANY: ");

# You can view the stocks of following companies
print(" GOOGLE-GOOG\n AMAZON-AMZN\n TESLA-TSLA\n APPLE-AAPL\n MICROSOFT-MSFT\n NETFLIX NFLX\n");
x=input("ENTER THE COMPANY: ")
z=int(input("NUMBER OF DAYS TO ANALYSE"))

present_day=date.today() #to store current day
day1=present_day.strftime("%Y-%m-%d") #current day in year-month-date format
final_date=day1 
day2=present_day-timedelta(days=z) #day before z days
day2=day2.strftime("%Y-%m-%d")
begin_date=day2

data=y.download(x,start=begin_date,end=final_date,progress=False) #stock data downloaded from yahoo finance
data["Date"]=data.index 

print("CHOOSE DESIRED VISUALIZATION:\n");
print("ENTER 1 FOR CANDLESTICK PLOT.\nENTER 2 FOR LINE PLOT\nENTER 3 FOR BOTH")
y=int(input("ENTER THE NUMBER: "));

if y==1: 
    fig=plg.Figure(data=plg.Candlestick(x=data["Date"],open=data["Open"],close=data["Close"],high=data["High"],low=data["Low"]))
    fig.update_layout(title="STOCK ANALYSIS") #TITLE OF PLOT
    fig.show()
elif y==2:
    py.figure()
    py.title("STOCK ANALYSIS") #TITLE OF PLOT
    sb.lineplot(data=data1,x="Date",y="Close")
    sb.despine()
elif y==3:
    fig=plg.Figure(data=plg.Candlestick(x=data["Date"],open=data["Open"],close=data["Close"],high=data["High"],low=data["Low"]))
    fig.update_layout(title="STOCK ANALYSIS")
    fig.show()
    py.figure()
    py.title("STOCK ANALYSIS")
    sb.lineplot(data=data1,x="Date",y="Close") #LINE PLOT
    sb.despine() #REMOVING SPINE
else:
    print("ENTER VALID NUMBER.\n")
# Out:
# USE THE GIVEN CODES AS INPUT FOR YOUR DESIRED COMPANY:
#  GOOGLE-GOOG
#  AMAZON-AMZN
#  TESLA-TSLA
#  APPLE-AAPL
#  MICROSOFT-MSFT
#  NETFLIX NFLX
#
# ENTER THE COMPANY: MSFT
# NUMBER OF DAYS TO ANALYSE170
# CHOOSE DESIRED VISUALIZATION:
#
# ENTER 1 FOR CANDLESTICK PLOT.
# ENTER 2 FOR LINE PLOT
# ENTER 3 FOR BOTH
# ENTER THE NUMBER: 1
# ...
